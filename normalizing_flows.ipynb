# %% [markdown]
# # Tutorial on GW Parameter Inference with Machine Learning
#
# ## IMPRS School on GWs
#
# ### notebook prepared by Stephen Green and presented by Nihar Gupte
# ### *stephen.green2@nottingham.ac.uk* , *Nihar.Gupte@aei.mpg.de*
#
# ---
#
# In this tutorial we will build a simple neural network to do **parameter estimation** using simulation-based inference.
#
# ### Steps
#
# 1. **Build a set of training waveforms.** We use the IMRPhenomPv2 model, parametrized only by masses.
# 2. **Build a posterior model $q(\theta | d)$** using a neural network. We consider two cases:
#     - Gaussian distribution with diagonal (learnable) covariance.
#     - Normalizing flow (masked autoregressive flow).
# 3. **Train the model to represent the posterior**, i.e., $q(\theta|d) \to p(\theta|d)$.
#     - During training, we add noise to waveforms to make simulated data.
# 4. **Evaluate** on test data.
#
# This should run in a few minutes on a laptop.
#
# ### Exercises
#
# 1. Add new parameters, beyond the masses
# 2. Use a more complicated waveform model
# 3. Make a PP plot
# 4. Experiment with the spline flow

# %% [markdown]
# ## Imports
#
# We use the [PyTorch](https://pytorch.org) ML library. Waveforms are generated using `lalsimulation`.

# %%
# If using colab, install appropriate packages.
# !pip install corner lalsuite glasflow
# Out:
# Requirement already satisfied: corner in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: lalsuite in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (7.22)
# Requirement already satisfied: glasflow in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: matplotlib>=2.1 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from corner) (3.7.5)
# Requirement already satisfied: astropy in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from lalsuite) (5.3.3)
# Requirement already satisfied: numpy>=1.7 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from lalsuite) (1.22.4)
# Requirement already satisfied: python-dateutil in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from lalsuite) (2.9.0.post0)
# Requirement already satisfied: scipy in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from lalsuite) (1.11.2)
# Requirement already satisfied: ligo-segments in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from lalsuite) (1.4.0)
# Requirement already satisfied: lscsoft-glue in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from lalsuite) (4.0.0)
# Requirement already satisfied: torch>=1.11.0 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from glasflow) (2.11.0)
# Requirement already satisfied: cycler>=0.10 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from matplotlib>=2.1->corner) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from matplotlib>=2.1->corner) (3.1.2)
# Requirement already satisfied: packaging>=20.0 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from matplotlib>=2.1->corner) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from matplotlib>=2.1->corner) (10.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from matplotlib>=2.1->corner) (1.2.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from matplotlib>=2.1->corner) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from matplotlib>=2.1->corner) (4.51.0)
# Requirement already satisfied: six>=1.5 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from python-dateutil->lalsuite) (1.16.0)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from torch>=1.11.0->glasflow) (13.2.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from torch>=1.11.0->glasflow) (2.28.9)
# Requirement already satisfied: setuptools<82 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from torch>=1.11.0->glasflow) (65.6.3)
# Requirement already satisfied: cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from torch>=1.11.0->glasflow) (13.0.2)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from torch>=1.11.0->glasflow) (0.8.0)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from torch>=1.11.0->glasflow) (3.4.5)
# Requirement already satisfied: fsspec>=0.8.5 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from torch>=1.11.0->glasflow) (2026.3.0)
# Requirement already satisfied: jinja2 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from torch>=1.11.0->glasflow) (3.1.6)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from torch>=1.11.0->glasflow) (9.19.0.56)
# Requirement already satisfied: sympy>=1.13.3 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from torch>=1.11.0->glasflow) (1.14.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from torch>=1.11.0->glasflow) (4.12.2)
# Requirement already satisfied: networkx>=2.5.1 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from torch>=1.11.0->glasflow) (3.4.2)
# Requirement already satisfied: triton==3.6.0 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from torch>=1.11.0->glasflow) (3.6.0)
# Requirement already satisfied: filelock in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from torch>=1.11.0->glasflow) (3.29.0)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->glasflow) (13.0.85)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->glasflow) (1.15.1.6)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->glasflow) (10.4.0.35)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->glasflow) (13.1.0.3)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->glasflow) (13.0.85)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->glasflow) (13.0.88)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->glasflow) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->glasflow) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->glasflow) (13.0.88)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->glasflow) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2->torch>=1.11.0->glasflow) (12.0.0.61)
# Requirement already satisfied: pyerfa>=2.0 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from astropy->lalsuite) (2.0.0.3)
# Requirement already satisfied: PyYAML>=3.13 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from astropy->lalsuite) (6.0.1)
# Requirement already satisfied: pyOpenSSL in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from lscsoft-glue->lalsuite) (24.1.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from cuda-bindings<14,>=13.0.3->torch>=1.11.0->glasflow) (1.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.11.0->glasflow) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->glasflow) (3.0.3)
# Requirement already satisfied: cryptography<43,>=41.0.5 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from pyOpenSSL->lscsoft-glue->lalsuite) (42.0.5)
# Requirement already satisfied: cffi>=1.12 in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from cryptography<43,>=41.0.5->pyOpenSSL->lscsoft-glue->lalsuite) (1.16.0)
# Requirement already satisfied: pycparser in /home/n/micromamba/envs/dingo-devel/lib/python3.10/site-packages (from cffi>=1.12->cryptography<43,>=41.0.5->pyOpenSSL->lscsoft-glue->lalsuite) (2.22)

# %%
import numpy as np
import matplotlib.pyplot as plt
import lal
import lalsimulation as LS
import corner

# %%
# PyTorch

import torch
from torch.utils.data import Dataset, DataLoader, random_split
from torch import nn
from torch.utils.data import DataLoader

# %%
# If running on Apple Silicon or CUDA is available, use the GPU.

if torch.backends.mps.is_available():
    device = "mps"
elif torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"

# %% [markdown]
# ## Training data

# %% [markdown]
# ### Signal model
#
# Generic quasi-circular inspirals depend on 15 parameters $\theta$:
# * Masses (2 parameters)
# * Spins (6 parameters)
# * Inclination
# * Sky position (2 parameters)
# * Luminosity distance
# * Time of arrival
# * Polarization
# * Phase
#
# We can write $h_I(\theta)$ for the signal in detector $I$.
#
# However, for this tutorial we will restrict consideration to only the masses, fixing everything else. Rather than considering waveforms in detectors, we will also only analyze the plus polarization.
#
# **Exercise:** Perform inference for more parameters, e.g., luminosity distance, inclination, phase, or aligned spins. (For sky position, it is necessary to project the polarizations onto detectors.)
#
# ### Noise
#
# Ultimately we must train on simulated data, which also include noise,
# $$
# d = h(\theta) + n, \qquad n \sim p_{S_n}(n).
# $$
# The noise is taken to be stationary Gaussian with some power spectral density $S_n$.
#
# Rather than creating complete simulated data sets in advance of training, **we only prepare the waveforms in advance, and we add noise realizations during training.** The reason for this is that we would like the training dataset to be as large as possible to reduce the risk of overfitting. Noise is fast to sample, so this can be done during training, and doing so effectively makes the training set much larger. Generally waveforms are slower to generate, so we re-use them in each epoch.

# %%
# Size of the training set.
num_samples = 10000

# Sample the masses over a uniform prior.
m_lower = 20.0  # solar masses
m_upper = 80.0
masses = m_lower + np.random.random((num_samples, 2)) * (m_upper - m_lower)

# Make sure m1 > m2
masses = np.sort(masses, axis=-1)
masses = np.flip(masses, axis=-1)

# %%
# Fixed parameters

distance = 1000  # Mpc
inclination = 0.0  # face on
spin1x = 0.0
spin1y = 0.0
spin1z = 0.0
spin2x = 0.0
spin2y = 0.0
spin2z = 0.0
phase = 0.0

# %%
# Waveform settings

approximant = 'IMRPhenomPv2'
f_min = 20.0
f_max = 512.0
T = 2.0

delta_f = 1 / T
nf = int(f_max / delta_f) + 1
f_array = np.linspace(0.0, f_max, num=nf)

# %%
# Generate the noise PSD. We take this to be the LIGO design sensitivity.

lalseries = lal.CreateREAL8FrequencySeries('', lal.LIGOTimeGPS(0), 0, delta_f, lal.DimensionlessUnit, nf)
LS.SimNoisePSD(lalseries, 0, LS.SimNoisePSDaLIGOZeroDetHighPowerPtr)
psd = lalseries.data.data
psd[:int(f_min/delta_f)] = 1
psd[-1] = psd[-2]

asd = np.sqrt(psd)

# %%
# Plot the ASD.

plt.plot(f_array, asd)
plt.xlim((f_min, f_max))
plt.ylim((3e-24, 3e-23))
plt.xscale('log')
plt.yscale('log')
plt.xlabel('f [Hz]')
plt.ylabel('ASD')
plt.show()

# %%
# Generate training waveforms

hp_list = []
hc_list = []

for i in range(num_samples):
    
    mass1, mass2 = masses[i]

    mass1_lal = mass1 * lal.MSUN_SI
    mass2_lal = mass2 * lal.MSUN_SI
    distance_lal = distance * 1e6 * lal.PC_SI
    approximant_lal = LS.GetApproximantFromString(approximant)

    hp, hc = LS.SimInspiralFD(
        mass1_lal, mass2_lal,
        spin1x, spin1y, spin1z, spin2x, spin2y, spin2z, 
        distance_lal, inclination, phase,
        0.0, 0.0, 0.0,  # longAscNodes, eccentricity, meanPerAno
        delta_f, f_min, f_max, 20.0,  # f_ref
        None,
        approximant_lal,
    )

    dt = 1 / hp.deltaF + (hp.epoch.gpsSeconds + hp.epoch.gpsNanoSeconds * 1e-9)
    time_shift = np.exp(-1j * 2 * np.pi * dt * f_array)
    
    hp = hp.data.data
    hc = hc.data.data

    hp *= time_shift
    hc *= time_shift
    
    hp[:int(f_min/delta_f)] = 0.0
    hc[:int(f_min/delta_f)] = 0.0
    
    # Whiten waveforms and rescale so that white noise has unit variance in each frequency bin.
    # This makes it easy to add noise, and also normalized data works better as input to neural networks.
    
    hp = hp / asd * np.sqrt(4.0 * delta_f)
    hc = hc / asd * np.sqrt(4.0 * delta_f)
    
    hp_list.append(hp)
    hc_list.append(hc)

hp = np.array(hp_list)
hc = np.array(hc_list)

# %%
# Sample waveform

plt.plot(f_array, hp[0].real)
plt.xscale('log')
plt.xlabel('$f$')
plt.ylabel('Re $h_+$')
plt.xlim((10, f_max))
plt.show()

# %%
# Overlay the signal on the detector noise.
#
# `hp` has been whitened (hp_whitened = hp_raw / asd * sqrt(4*delta_f)), so recover the raw
# waveform first. Then use the characteristic strain so signal and noise are in the same units
# and directly comparable per log-frequency bin:
#   signal: h_c(f) = 2 * f * |h(f)|
#   noise:  h_n(f) = sqrt(f * S_n(f))

hp_raw = hp[0] * asd / np.sqrt(4.0 * delta_f)

plt.loglog(f_array, 2 * f_array * np.abs(hp_raw), label=r'signal: $2f\,|h_+(f)|$')
plt.loglog(f_array, np.sqrt(f_array * psd), label=r'noise: $\sqrt{f\,S_n(f)}$')
plt.ylim((3e-24, 3e-20))
plt.xlim((f_min, f_max))
plt.xlabel('$f$ [Hz]')
plt.ylabel('characteristic strain')
plt.legend()
plt.show()

# %%
**Question for class: Given this PSD, what would happen if we set the distance to 20 GPC, what would our network learn to output**
# Out:
#   Cell In[160], line 1
#     **Question for class: Given this PSD, what would happen if we set the distance to 20 GPC, what would our network learn to output**
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Package into a PyTorch Dataset
#
# The `Dataset` is a convenient class for storing and accessing pairs of parameters and associated data. It must define the following methods:
#
# * `__len__()`: Return total number of samples in the dataset.
# * `__getitem__(idx)`: Retrieve a $(\theta, d)$ pair of parameters and data. We use this method to also add (in real time) a noise realization to each simulated waveform. (Therefore repeated calls will give different noise realizations).
#
# For now, we will only make use of the plus polarization for simplicity.
#
# **Exercise:** Extend this to include more parameters. Some parameters, e.g., luminosity distance, can be easily transformed. For these, it makes sense to select them in real time, like for the noise.

# %%
# Parameters
#
# This is just the masses. It's better to sample in (Mc, q) rather than (m1, m2) because the posterior is more Gaussian.

m1 = masses[:, 0]
m2 = masses[:, 1]

Mc = (m1 * m2)**(3/5) / (m1 + m2)**(1/5)
q = m2 / m1

parameters = np.stack((Mc, q), axis=1).astype(np.float32)

# %%
# For best training, parameters should be standardized (zero mean, unit variance across the training set)

parameters_mean = np.mean(parameters, axis=0)
parameters_std = np.std(parameters, axis=0)

parameters_standardized = (parameters - parameters_mean) / parameters_std

# %%
# Waveforms
#
# Truncate the arrays to remove zeros below f_min, and repackage real and imaginary parts
#
# Only consider h_plus for now

lower_cut = int(f_min / delta_f)
waveforms = np.hstack((hp.real[:, lower_cut:], hp.imag[:, lower_cut:])).astype(np.float32)

# %%
class WaveformDataset(Dataset):
    
    def __init__(self, parameters, waveforms):
        self.parameters = parameters
        self.waveforms = waveforms

    def __len__(self):
        return len(self.parameters)

    def __getitem__(self, idx):
        params = self.parameters[idx]
        signal = self.waveforms[idx]
        
        # Add unit normal noise to the signal
        noise = np.random.normal(size = signal.shape).astype(np.float32)
        data = signal + noise
        
        return torch.tensor(data, device=device), torch.tensor(params, device=device)

# %%
waveform_dataset = WaveformDataset(parameters_standardized, waveforms)

# %%
# We can sample from the WaveformDataset. This gives us pairs of data and parameters, different noise realizations each time.

x, y = waveform_dataset[0]
x = x.cpu()  # Careful to put data back onto CPU.
plt.plot(x)
plt.show()

# %% [markdown]
# ## Gaussian posterior model
#
# We now try to fit the posterior using a Gaussian model, i.e.,
#
# $$
# q(\theta|d) = \mathcal{N}(\mu(d), \Sigma(d)) (\theta).
# $$
# Here $\mu$ and $\Sigma$ are the mean and covariance matrix describing the Gaussian, and they are given as the output of a neural network, which takes as input the data $d$. Additionally, we constrain $\Sigma$ to be diagonal, so we only learn the variance in each parameter, and we do not allow for correlations between parameters in the posterior. (**Exercise:** Lift this restriction.)

# %% [markdown]
# ### Model construction
#
# Neural networks are constructed by subclassing `nn.Module`.
#
# This has to implement an `__init__()` and `forward()` method.

# %%
# Neural networks are constructed by subclassing nn.Module
#
# This has to implement an __init__() and forward() method

class GaussianNeuralNetwork(nn.Module):
    
    def __init__(self, input_dim, hidden_dims, output_dim, activation=nn.ReLU()):
        super(GaussianNeuralNetwork, self).__init__()
        
        # Hidden layers
        hidden_net_list = []
        hidden_net_list.append(
            nn.Linear(input_dim, hidden_dims[0]))
        for i in range(1, len(hidden_dims)):
            hidden_net_list.append(nn.Linear(hidden_dims[i-1], hidden_dims[i]))
        self.hidden_net_list = nn.ModuleList(hidden_net_list)
        
        # Output layers
        self.output_mean = nn.Linear(hidden_dims[-1], output_dim)
        self.output_log_sigma = nn.Linear(hidden_dims[-1], output_dim)
        
        # Activation function
        self.activation = activation
        
    def forward(self, x):
        """Pass x through all the layers of the network and return the Gaussian distribution"""
        
        h = x
        for layer in self.hidden_net_list:
            h = self.activation(layer(h))

        # Output layer defines a Gaussian
        mean = self.output_mean(h)
        log_sigma = self.output_log_sigma(h)
        sigma = torch.exp(log_sigma)
        
        # Create the Gaussian distribution
        dist = torch.distributions.MultivariateNormal(loc=mean, scale_tril=torch.diag_embed(sigma))
        
        return dist

# %%
input_dim = waveforms.shape[-1]
output_dim = parameters.shape[-1]
hidden_dims = [512, 256, 128, 64, 32]

model = GaussianNeuralNetwork(input_dim, hidden_dims, output_dim)

model.to(device)  # Put model on GPU, if available.
# Out:
# GaussianNeuralNetwork(
#   (hidden_net_list): ModuleList(
#     (0): Linear(in_features=1970, out_features=512, bias=True)
#     (1): Linear(in_features=512, out_features=256, bias=True)
#     (2): Linear(in_features=256, out_features=128, bias=True)
#     (3): Linear(in_features=128, out_features=64, bias=True)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#   )
#   (output_mean): Linear(in_features=32, out_features=2, bias=True)
#   (output_log_sigma): Linear(in_features=32, out_features=2, bias=True)
#   (activation): ReLU()
# )

# %% [markdown]
# ### Training

# %%
# Split the dataset into training and test sets.
# We use the test set to make sure the network properly generalizes to data that it has not seen in training, i.e., it does not overfit.

train_fraction = 0.8
num_train = int(round(train_fraction * num_samples))
num_test = num_samples - num_train
train_dataset, test_dataset = random_split(waveform_dataset, [num_train, num_test])

# The DataLoader is used to obtain samples form the Dataset during training.

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
# The DataLoaders iterate over samples, returning torch tensors containing a batch of data

train_features, train_labels = next(iter(train_dataloader))

# %%
train_features
# Out:
# tensor([[ 0.4144, -4.0252, -4.7921,  ...,  1.0265, -1.3213, -0.9934],
#         [-1.9138, -3.7035, -5.2947,  ..., -0.2592,  0.4972, -1.5251],
#         [ 4.2946,  2.9049,  1.4688,  ..., -2.3517, -1.3208, -0.2054],
#         ...,
#         [ 2.0286,  0.6455, -2.5915,  ...,  2.2408, -1.5364, -0.7623],
#         [ 1.0533,  1.2124, -0.6853,  ..., -0.4046,  0.8883, -1.7329],
#         [ 1.3276, -2.8746,  0.2039,  ...,  0.8340, -0.3125, -1.6208]])

# %%
train_features.shape
# Out:
# torch.Size([64, 1970])

# %%
# We use the Adam optimizer.

optimizer = torch.optim.Adam(model.parameters())

# %%
# Training and test loops

def train_loop(dataloader, model, optimizer):
 
    size = len(dataloader.dataset)
    train_loss = 0
    
    for batch, (X, y) in enumerate(dataloader):
        # Compute negative log probability loss
        dist = model(X)        
        loss = - dist.log_prob(y)
        
        train_loss += loss.detach().sum()
        loss = loss.mean()

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 50 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"Loss: {loss:>7f}  [{current:>5d}/{size:>5d} samples]")
            
    average_loss = train_loss.item() / size
    print('Average loss: {:.4f}'.format(average_loss))
    return average_loss
            
        
        
def test_loop(dataloader, model):
    size = len(dataloader.dataset)
    test_loss = 0

    with torch.no_grad():
        for X, y in dataloader:
            dist = model(X)
            loss = - dist.log_prob(y)
            test_loss += loss.sum()

    test_loss = test_loss.item() / size
    print(f"Test loss: {test_loss:>8f} \n")
    return test_loss

# %%
# Train for 20 epochs. 

epochs = 20
train_history = []
test_history = []
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    loss = train_loop(train_dataloader, model, optimizer)
    train_history.append(loss)
    loss = test_loop(test_dataloader, model)
    test_history.append(loss)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Loss: 2.778849  [    0/ 8000 samples]
# Loss: 1.088138  [ 3200/ 8000 samples]
# Loss: 0.602324  [ 6400/ 8000 samples]
# Average loss: 0.8888
# Test loss: 0.156569
#
# Epoch 2
# -------------------------------
# Loss: 0.023737  [    0/ 8000 samples]
# Loss: 0.145495  [ 3200/ 8000 samples]
# Loss: -0.521990  [ 6400/ 8000 samples]
# Average loss: -0.0800
# Test loss: -0.300633
#
# Epoch 3
# -------------------------------
# Loss: -0.417693  [    0/ 8000 samples]
# Loss: -0.481894  [ 3200/ 8000 samples]
# Loss: 0.043595  [ 6400/ 8000 samples]
# Average loss: -0.4802
# Test loss: -0.261502
#
# Epoch 4
# -------------------------------
# Loss: 0.058844  [    0/ 8000 samples]
# Loss: -0.742736  [ 3200/ 8000 samples]
# Loss: -0.907734  [ 6400/ 8000 samples]
# Average loss: -0.8937
# Test loss: -1.066461
#
# Epoch 5
# -------------------------------
# Loss: -1.094734  [    0/ 8000 samples]
# Loss: -0.927749  [ 3200/ 8000 samples]
# Loss: -1.507505  [ 6400/ 8000 samples]
# Average loss: -1.1064
# Test loss: -1.229709
#
# Epoch 6
# -------------------------------
# Loss: -1.192888  [    0/ 8000 samples]
# Loss: -1.495691  [ 3200/ 8000 samples]
# Loss: -1.584468  [ 6400/ 8000 samples]
# Average loss: -1.5063
# Test loss: -1.446236
#
# Epoch 7
# -------------------------------
# Loss: -1.450169  [    0/ 8000 samples]
# Loss: -1.591294  [ 3200/ 8000 samples]
# Loss: -1.679954  [ 6400/ 8000 samples]
# Average loss: -1.4482
# Test loss: -1.888478
#
# Epoch 8
# -------------------------------
# Loss: -1.794111  [    0/ 8000 samples]
# Loss: -1.778409  [ 3200/ 8000 samples]
# Loss: -1.515332  [ 6400/ 8000 samples]
# Average loss: -1.6350
# Test loss: -1.851628
#
# Epoch 9
# -------------------------------
# Loss: -1.707040  [    0/ 8000 samples]
# Loss: -2.198931  [ 3200/ 8000 samples]
# Loss: -1.780180  [ 6400/ 8000 samples]
# Average loss: -1.8543
# Test loss: -1.916877
#
# Epoch 10
# -------------------------------
# Loss: -1.807216  [    0/ 8000 samples]
# Loss: -1.884128  [ 3200/ 8000 samples]
# Loss: -1.970850  [ 6400/ 8000 samples]
# Average loss: -1.9295
# Test loss: -1.891411
#
# Epoch 11
# -------------------------------
# Loss: -2.028627  [    0/ 8000 samples]
# Loss: -1.684067  [ 3200/ 8000 samples]
# Loss: -2.438256  [ 6400/ 8000 samples]
# Average loss: -2.0252
# Test loss: -1.786721
#
# Epoch 12
# -------------------------------
# Loss: -1.559704  [    0/ 8000 samples]
# Loss: -1.932576  [ 3200/ 8000 samples]
# Loss: -2.312907  [ 6400/ 8000 samples]
# Average loss: -2.0380
# Test loss: -1.854167
#
# Epoch 13
# -------------------------------
# Loss: -1.485263  [    0/ 8000 samples]
# Loss: -1.905015  [ 3200/ 8000 samples]
# Loss: -2.302786  [ 6400/ 8000 samples]
# Average loss: -2.1121
# Test loss: -2.141207
#
# Epoch 14
# -------------------------------
# Loss: -2.206090  [    0/ 8000 samples]
# Loss: -2.231680  [ 3200/ 8000 samples]
# Loss: -1.563514  [ 6400/ 8000 samples]
# Average loss: -2.1599
# Test loss: -2.188456
#
# Epoch 15
# -------------------------------
# Loss: -2.517287  [    0/ 8000 samples]
# Loss: -1.546268  [ 3200/ 8000 samples]
# Loss: -2.257462  [ 6400/ 8000 samples]
# Average loss: -2.1938
# Test loss: -2.245862
#
# Epoch 16
# -------------------------------
# Loss: -2.555146  [    0/ 8000 samples]
# Loss: -2.230982  [ 3200/ 8000 samples]
# Loss: -1.970293  [ 6400/ 8000 samples]
# Average loss: -2.2005
# Test loss: -1.658835
#
# Epoch 17
# -------------------------------
# Loss: -1.637230  [    0/ 8000 samples]
# Loss: -2.067284  [ 3200/ 8000 samples]
# Loss: -2.494951  [ 6400/ 8000 samples]
# Average loss: -2.2426
# Test loss: -2.313959
#
# Epoch 18
# -------------------------------
# Loss: -2.289191  [    0/ 8000 samples]
# Loss: -2.228184  [ 3200/ 8000 samples]
# Loss: -2.239066  [ 6400/ 8000 samples]
# Average loss: -2.2501
# Test loss: -2.516032
#
# Epoch 19
# -------------------------------
# Loss: -2.864808  [    0/ 8000 samples]
# Loss: -2.268500  [ 3200/ 8000 samples]
# Loss: -2.574572  [ 6400/ 8000 samples]
# Average loss: -2.4182
# Test loss: -2.506158
#
# Epoch 20
# -------------------------------
# Loss: -2.138294  [    0/ 8000 samples]
# Loss: -2.678419  [ 3200/ 8000 samples]
# Loss: -2.512597  [ 6400/ 8000 samples]
# Average loss: -2.4245
# Test loss: -2.456930
#
# Done!

# %%
epochs = np.arange(1, len(train_history) + 1)
plt.plot(epochs, train_history, label = 'train loss')
plt.plot(epochs, test_history, label = 'test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# We see that the test loss drops just as fast as the train. Since these curves coincide we conclude that the model is not overfitting.
#
# If we trained longer, or used a more powerful model, we might find a difference between these curves. If this happens, increase the size of the training set.
#
# **Question for class: Would you expect the injected value to always be at the peak of the Gaussian?**
# **Question for class: Is there a problem with the joint distribution?**

# %%
num_posteriors = 5
num_samples = 10000

model.eval()

for n in range(num_posteriors):
    with torch.no_grad():
        test_x, test_y = test_dataset[n]
    
        # Predict a posterior
        dist = model(test_x)
    
        # Sample the posterior
        pred_samples = dist.sample((10000,)).cpu().numpy()

        # Undo the standardization
        pred_samples = parameters_std * pred_samples + parameters_mean
        truth = parameters_std * test_y.cpu().numpy() + parameters_mean

    # Plot
    corner.corner(pred_samples, truths=truth, labels=['$M_c$', '$q$'])
    plt.show()

# %% [markdown]
# ## Normalizing flow
#
# Normalizing flows allow for much more general probability distributions, as needed to represent GW posterior distributions in 15D. A normalizing flow represents the distribution in terms of a mapping $f_d:\mathbb R^D \to \mathbb R^D$ from a *base distribution* $\pi(u) = \mathcal N(0,1)^D$,
# $$
# q(\theta | d) = \pi(f_d^{-1}(\theta)) | \det J_{f_d}^{-1} |.
# $$
# To sample $\theta \sim q(\theta|d)$, first sample $u\sim \pi(u)$, then apply the mapping and set $\theta = f_d(u)$. By having $f_d$ depend on the data $d$, this describes a conditional distribution, as needed for amortized inference.
#
# To train the flow, it is necessary also to evaluate the density. This can be done by evaluating the right hand side of the equation above, provided two properties hold:
# 1. $f_d$ invertible
# 2. $f_d$ has simple Jacobian determinant
#
# The trick then is to construct suitable $f_d$ such that these properties hold. A simple model is a [Masked Autoregressive Flow (MAF)](https://arxiv.org/abs/1705.07057).

# %% [markdown]
# ### Model construction
#
# Normalizing flows are constructed as a sequence of discrete steps, each of which is relatively simple. For an autoregressive flow step $n$, we write
# $$
# q^{(n)}(\theta | d) = \prod_{i=1}^D q^{(n)}(\theta_i | \theta_{1:i-1}, d),
# $$
#
#
# $$
# q^{(n)}(\theta \mid d) = q^{(n)}(\theta_1 \mid d)\cdot q^{(n)}(\theta_2 \mid \theta_1, d)
# $$
#
#
# where each factor takes a particular parametrized form. For the MAF, this is taken to be a univariate normal distribution,
# $$
# q^{(n)}(\theta_i | \theta_{1:i-1}, d) = \mathcal{N}\left(\mu_i^{(n)}(\theta_{1:i-1},d), \sigma_i^{(n)}(\theta_{1:i-1},d)\right)
# $$
# so that the corresponding mapping is an affine transformation. The means and variances are given as output of a neural network, and are learned. There is in fact a smart way of representing all of these quantities for a single step in one neural network with masking called [MADE](https://arxiv.org/abs/1502.03509). Between each flow step we also randomize the order of the parameters.
#
# **Question for class: Why is the above form alone bad?**
#
# For the normalizing flow, we use an off-the-shelf library rather than coding it ourselves. Although we will use a MAF for our example, code for a [spline flow](https://arxiv.org/abs/1906.04032) is also included. **Exercise:** Try it out.

# %%
# The glasflow library is a wrapper for nflows (https://github.com/bayesiains/nflows), which implements many different flows.

from glasflow.nflows import transforms, distributions, flows
import glasflow.nflows as nflows
import glasflow.nflows.nn.nets as nflows_nets

# %%
device = 'cpu'  # For some reason, "mps" does not work here.

# %%
# Code here is adapted from examples in the neural spline flow repository, https://github.com/bayesiains/nsf

# These functions create the transform sequence.

def create_base_transform(
    i: int,
    param_dim: int,
    context_dim: int = None,
    hidden_dim: int = 512,
    num_transform_blocks: int = 2,
    batch_norm: bool = False,
    base_transform_type: str = "maf",
):
    
    activation_fn = nn.ELU()

    if base_transform_type == "maf":
        return transforms.MaskedAffineAutoregressiveTransform(
            param_dim,
            hidden_features=hidden_dim,
            context_features=context_dim,
            num_blocks=num_transform_blocks,
            activation=activation_fn,
            use_batch_norm=batch_norm,
        )

    elif base_transform_type == "rq-coupling":
        if param_dim == 1:
            mask = torch.tensor([1], dtype=torch.uint8)
        else:
            mask = nflows.utils.create_alternating_binary_mask(
                param_dim, even=(i % 2 == 0)
            )
        return transforms.PiecewiseRationalQuadraticCouplingTransform(
            mask=mask,
            transform_net_create_fn=(
                lambda in_features, out_features: nflows_nets.ResidualNet(
                    in_features=in_features,
                    out_features=out_features,
                    hidden_features=hidden_dim,
                    context_features=context_dim,
                    num_blocks=num_transform_blocks,
                    activation=activation_fn,
                    use_batch_norm=batch_norm,
                )
            ),
            num_bins=8,
            tails="linear",
            tail_bound=1.0,
            apply_unconditional_transform=False,
        )

    else:
        raise ValueError


def create_linear_transform(param_dim: int):
    return transforms.CompositeTransform(
        [
            transforms.RandomPermutation(features=param_dim),
            transforms.LULinear(param_dim, identity_init=True),
        ]
    )


def create_transform(
    num_flow_steps: int, param_dim: int, context_dim: int, base_transform_kwargs: dict
):
    return transforms.CompositeTransform(
        [
            transforms.CompositeTransform(
                [
                    create_linear_transform(param_dim),
                    create_base_transform(
                        i, param_dim, context_dim=context_dim, **base_transform_kwargs
                    ),
                ]
            )
            for i in range(num_flow_steps)
        ]
        + [create_linear_transform(param_dim)]
    )

# %%
# The entire flow model consists of a standard normal base distribution, followed by the transform.

transform = create_transform(num_flow_steps = 3,
                             param_dim = parameters.shape[-1],
                             context_dim = waveforms.shape[-1],
                             base_transform_kwargs = {"base_transform_type": "maf"})

base_distribution = distributions.StandardNormal(shape=[parameters.shape[-1]])

model = flows.Flow(transform, base_distribution)

# %%
model.to(device)
# Out:
# Flow(
#   (_transform): CompositeTransform(
#     (_transforms): ModuleList(
#       (0-2): 3 x CompositeTransform(
#         (_transforms): ModuleList(
#           (0): CompositeTransform(
#             (_transforms): ModuleList(
#               (0): RandomPermutation()
#               (1): LULinear()
#             )
#           )
#           (1): MaskedAffineAutoregressiveTransform(
#             (autoregressive_net): MADE(
#               (initial_layer): MaskedLinear(in_features=2, out_features=512, bias=True)
#               (context_layer): Linear(in_features=1970, out_features=512, bias=True)
#               (activation): ELU(alpha=1.0)
#               (blocks): ModuleList(
#                 (0-1): 2 x MaskedResidualBlock(
#                   (context_layer): Linear(in_features=1970, out_features=512, bias=True)
#                   (linear_layers): ModuleList(
#                     (0-1): 2 x MaskedLinear(in_features=512, out_features=512, bias=True)
#                   )
#                   (activation): ELU(alpha=1.0)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (final_layer): MaskedLinear(in_features=512, out_features=4, bias=True)
#             )
#           )
#         )
#       )
#       (3): CompositeTransform(
#         (_transforms): ModuleList(
#           (0): RandomPermutation()
#           (1): LULinear()
#         )
#       )
#     )
#   )
#   (_distribution): StandardNormal()
#   (_embedding_net): Identity()
# )

# %% [markdown]
# #### Reading the printed structure
#
# For `param_dim=2` ($\theta = (M_c, q)$), `context_dim=1970` (whitened waveform $d$), `num_flow_steps=3`, `hidden_dim=512`:
#
# - **`Flow`** — the full model $q(\theta|d) = \pi(f_d^{-1}(\theta))\,|\det J|$. Holds a base distribution $\pi$ and an invertible transform $f_d$.
# - **`_transform: CompositeTransform`** — $f_d$ as a stack of sub-transforms. The log-det Jacobian is a sum over steps.
# - **`3 x CompositeTransform`** — the three flow steps. Each is a linear reshuffle followed by a masked autoregressive affine transform.
#     - **`RandomPermutation + LULinear`** — shuffles the 2 parameter dims and applies a learnable 2×2 invertible matrix (LU-parameterized for a cheap log-det). Without this, the autoregressive ordering would never change between steps.
#     - **`MaskedAffineAutoregressiveTransform`** — the MAF step: $\theta_i \leftarrow (\theta_i - \mu_i)/\sigma_i$ where $\mu_i, \sigma_i$ depend only on $\theta_{<i}$ and $d$. The triangular Jacobian makes the log-det cheap.
#         - **`MADE`** — one masked MLP that emits all $(\mu_i, \log \sigma_i)$ in a single pass. Weight masking enforces the autoregressive property end-to-end.
#             - `initial_layer` (2 → 512): lifts $\theta$ into hidden space.
#             - `context_layer` (1970 → 512): injects the waveform $d$. Unmasked, because context can influence every output.
#             - `2 × MaskedResidualBlock`: two residual blocks, each re-injects $d$ and has two masked 512→512 layers with ELU.
#             - `final_layer` (512 → 4): outputs $2 \times$ `param_dim` = one $(\mu, \log \sigma)$ per parameter.
# - **Final `RandomPermutation + LULinear`** — one more rotation before hitting the base distribution.
# - **`_distribution: StandardNormal`** — $\pi(u) = \mathcal{N}(0, I)$ on $\mathbb{R}^2$.
# - **`_embedding_net: Identity`** — no preprocessing of $d$ (in a bigger setup you'd insert a CNN here to compress the waveform).

# %% [markdown]
# ### Training

# %%
# Split the dataset into training and test sets

train_fraction = 0.8
num_train = int(round(train_fraction * num_samples))
num_test = num_samples - num_train
train_dataset, test_dataset = random_split(waveform_dataset, [num_train, num_test])

# The DataLoader is used in training

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
# We use the Adam optimizer. He is magical.

optimizer = torch.optim.Adam(model.parameters(), lr=2e-4)

# %%
# Training and test loops

def train_loop(dataloader, model, optimizer):

    model.train()
 
    size = len(dataloader.dataset)
    train_loss = 0
    
    for batch, (X, y) in enumerate(dataloader):
        # Compute negative log probability loss  
        loss = - model.log_prob(y, X)
        
        train_loss += loss.detach().sum()
        loss = loss.mean()

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 50 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"Loss: {loss:>7f}  [{current:>5d}/{size:>5d} samples]")
            
    average_loss = train_loss.item() / size
    print('Average loss: {:.4f}'.format(average_loss))
    return average_loss
            
        
        
def test_loop(dataloader, model):

    model.eval()
    
    size = len(dataloader.dataset)
    test_loss = 0

    with torch.no_grad():
        for X, y in dataloader:
            loss = - model.log_prob(y, X)
            test_loss += loss.sum()

    test_loss = test_loss.item() / size
    print(f"Test loss: {test_loss:>8f} \n")
    return test_loss

# %%
epochs = 20
train_history = []
test_history = []
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    loss = train_loop(train_dataloader, model, optimizer)
    train_history.append(loss)
    loss = test_loop(test_dataloader, model)
    test_history.append(loss)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Loss: 4.741304  [    0/ 8000 samples]
# Loss: 0.975308  [ 3200/ 8000 samples]
# Loss: 0.146043  [ 6400/ 8000 samples]
# Average loss: 1.2273
# Test loss: 0.419596
#
# Epoch 2
# -------------------------------
# Loss: 0.347720  [    0/ 8000 samples]
# Loss: 0.097740  [ 3200/ 8000 samples]
# Loss: -0.080865  [ 6400/ 8000 samples]
# Average loss: -0.1369
# Test loss: -0.315117
#
# Epoch 3
# -------------------------------
# Loss: -0.590372  [    0/ 8000 samples]
# Loss: -0.945213  [ 3200/ 8000 samples]
# Loss: -1.161418  [ 6400/ 8000 samples]
# Average loss: -0.9516
# Test loss: -1.210420
#
# Epoch 4
# -------------------------------
# Loss: -1.230939  [    0/ 8000 samples]
# Loss: -1.415015  [ 3200/ 8000 samples]
# Loss: -1.291134  [ 6400/ 8000 samples]
# Average loss: -1.3698
# Test loss: -1.679794
#
# Epoch 5
# -------------------------------
# Loss: -1.824825  [    0/ 8000 samples]
# Loss: -1.511394  [ 3200/ 8000 samples]
# Loss: -1.527851  [ 6400/ 8000 samples]
# Average loss: -1.6089
# Test loss: -1.604615
#
# Epoch 6
# -------------------------------
# Loss: -1.772979  [    0/ 8000 samples]
# Loss: -1.806035  [ 3200/ 8000 samples]
# Loss: -2.099030  [ 6400/ 8000 samples]
# Average loss: -1.8174
# Test loss: -1.985436
#
# Epoch 7
# -------------------------------
# Loss: -2.007650  [    0/ 8000 samples]
# Loss: -2.360715  [ 3200/ 8000 samples]
# Loss: -2.091918  [ 6400/ 8000 samples]
# Average loss: -2.0228
# Test loss: -2.076458
#
# Epoch 8
# -------------------------------
# Loss: -2.188579  [    0/ 8000 samples]
# Loss: -2.339646  [ 3200/ 8000 samples]
# Loss: -1.769404  [ 6400/ 8000 samples]
# Average loss: -2.1215
# Test loss: -2.222090
#
# Epoch 9
# -------------------------------
# Loss: -2.069725  [    0/ 8000 samples]
# Loss: -2.167211  [ 3200/ 8000 samples]
# Loss: -2.374161  [ 6400/ 8000 samples]
# Average loss: -2.2977
# Test loss: -2.175019
#
# Epoch 10
# -------------------------------
# Loss: -2.369876  [    0/ 8000 samples]
# Loss: -2.222803  [ 3200/ 8000 samples]
# Loss: -2.296042  [ 6400/ 8000 samples]
# Average loss: -2.3782
# Test loss: -2.457903
#
# Epoch 11
# -------------------------------
# Loss: -2.488094  [    0/ 8000 samples]
# Loss: -2.611295  [ 3200/ 8000 samples]
# Loss: -2.386726  [ 6400/ 8000 samples]
# Average loss: -2.4987
# Test loss: -2.566124
#
# Epoch 12
# -------------------------------
# Loss: -2.770340  [    0/ 8000 samples]
# Loss: -2.373183  [ 3200/ 8000 samples]
# Loss: -2.311983  [ 6400/ 8000 samples]
# Average loss: -2.5765
# Test loss: -2.673377
#
# Epoch 13
# -------------------------------
# Loss: -2.888392  [    0/ 8000 samples]
# Loss: -2.294398  [ 3200/ 8000 samples]
# Loss: -2.525525  [ 6400/ 8000 samples]
# Average loss: -2.5767
# Test loss: -2.723473
#
# Epoch 14
# -------------------------------
# Loss: -3.157115  [    0/ 8000 samples]
# Loss: -2.618670  [ 3200/ 8000 samples]
# Loss: -2.864043  [ 6400/ 8000 samples]
# Average loss: -2.7406
# Test loss: -2.787100
#
# Epoch 15
# -------------------------------
# Loss: -2.716568  [    0/ 8000 samples]
# Loss: -2.806512  [ 3200/ 8000 samples]
# Loss: -2.459210  [ 6400/ 8000 samples]
# Average loss: -2.8306
# Test loss: -3.046492
#
# Epoch 16
# -------------------------------
# Loss: -2.669790  [    0/ 8000 samples]
# Loss: -2.661524  [ 3200/ 8000 samples]
# Loss: -3.069341  [ 6400/ 8000 samples]
# Average loss: -2.8276
# Test loss: -2.989957
#
# Epoch 17
# -------------------------------
# Loss: -2.913695  [    0/ 8000 samples]
# Loss: -3.106345  [ 3200/ 8000 samples]
# Loss: -3.261326  [ 6400/ 8000 samples]
# Average loss: -2.9964
# Test loss: -3.030521
#
# Epoch 18
# -------------------------------
# Loss: -2.967727  [    0/ 8000 samples]
# Loss: -2.818885  [ 3200/ 8000 samples]
# Loss: -3.089416  [ 6400/ 8000 samples]
# Average loss: -3.0135
# Test loss: -3.159543
#
# Epoch 19
# -------------------------------
# Loss: -3.459822  [    0/ 8000 samples]
# Loss: -2.991005  [ 3200/ 8000 samples]
# Loss: -3.394701  [ 6400/ 8000 samples]
# Average loss: -3.1052
# Test loss: -3.101921
#
# Epoch 20
# -------------------------------
# Loss: -3.567258  [    0/ 8000 samples]
# Loss: -2.900198  [ 3200/ 8000 samples]
# Loss: -3.502531  [ 6400/ 8000 samples]
# Average loss: -3.0987
# Test loss: -3.160691
#
# Done!

# %%
epochs = np.arange(1, len(train_history) + 1)
plt.plot(epochs, train_history, label = 'train loss')
plt.plot(epochs, test_history, label = 'test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluation

# %%
num_posteriors = 5
num_eval_samples = 10000

model.eval()

for n in range(num_posteriors):

    with torch.no_grad():
    
        test_x, test_y = test_dataset[n]
       
        # Sample the posterior
        test_x = test_x.expand(num_eval_samples, *x.shape)
        pred_samples = model.sample(1, test_x).squeeze(1).cpu().numpy()
    
        # Undo the standardization
        pred_samples = parameters_std * pred_samples + parameters_mean
        truth = parameters_std * test_y.cpu().numpy() + parameters_mean
    
        # Plot
        corner.corner(pred_samples, truths=truth, labels=['$M_c$', '$q$'])
        plt.show()

# %% [markdown]
# ### Visualizing the flow
#
# We can watch the trained flow warp a blob of samples from the base distribution $\mathcal{N}(0, I)$ into the posterior. Fix a test waveform as context $d$, sample $u \sim \mathcal{N}(0, I)$, and apply the inverse of each sub-transform one at a time, plotting the 2D cloud after each step. The first panel is the base distribution; the last panel is a sample from $q(\theta | d)$ (in standardized coordinates). The red cross marks the ground-truth parameters.

# %%
model.eval()

n_samples = 2000

with torch.no_grad():
    test_x, test_y = test_dataset[0]
    context = test_x.expand(n_samples, *test_x.shape)

    # Sample from the base distribution.
    z = torch.randn(n_samples, parameters.shape[-1], device=device)

    snapshots = [z.cpu().numpy()]
    labels = [r'base: $u \sim \mathcal{N}(0, I)$']

    # model._transform is a CompositeTransform. Its inverse applies the sub-transforms in reverse
    # order, so we step through them manually here to capture intermediate point clouds.
    sub_transforms = list(model._transform._transforms)
    n_sub = len(sub_transforms)
    for i, t in enumerate(reversed(sub_transforms)):
        z, _ = t.inverse(z, context)
        step_idx = n_sub - 1 - i
        snapshots.append(z.cpu().numpy())
        name = type(sub_transforms[step_idx]).__name__
        labels.append(f'after inverse of\nsub-transform {step_idx}\n({name})')

truth_std = test_y.cpu().numpy()

fig, axes = plt.subplots(1, len(snapshots), figsize=(3.2 * len(snapshots), 3.5))
for ax, snap, label in zip(axes, snapshots, labels):
    ax.set_title(label, fontsize=9)
    ax.set_xlabel(r'$\theta_0$ (standardized)')
    ax.scatter(snap[:, 0], snap[:, 1], s=3, alpha=0.3)
axes[0].set_ylabel(r'$\theta_1$ (standardized)')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Exercise:** Try learning $(m_1, m_2)$ rather than $(M_c, q)$. The flow should be able to represent the distinct shape.
